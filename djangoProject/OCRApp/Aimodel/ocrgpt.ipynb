# %%
import requests

# Replace 'YOUR_API_KEY' with your OCR API key
api_key = 'K82267638488957'

# URL of the Tesseract OCR API
api_url = 'https://api.ocr.space/parse/image'

# Path to the image file you want to process
image_path = 'C:\\Users\\GO\\Desktop\\aa.jpg'

# Prepare the headers with the API key
headers = {
    'apikey': api_key
}

# Send a POST request to the Tesseract OCR API
response = requests.post(api_url, headers=headers, files={'image': (image_path, open(image_path, 'rb'))})

# Check if the request was successful
if response.status_code == 200:
    result = response.json()
    extracted_text = result.get('ParsedResults')[0].get('ParsedText')
    print('Text extracted from the image:')
    print(extracted_text)
else:
    print('Error:', response.status_code)
    print(response.text)
# Out:
# Text extracted from the image:
# LISTE DE FOURNITURES
# Classe de CM2
# M. Marchand
# 4 stylos (bleu, noir, rouge vert)
# 4 surligneurs (4 couleurs différentes)
# 1 crayon å papier
# 1 gomme
# 1 taille-crayon
# 1 regle graduée de 30 cm
# 1 équerre
# 1 compas
# 1 rapporteur
# 1 paire de ciseaux
# 1 tube de colle
# 1 rouleau de scotch
# Des feutres
# Des crayons de couleur
# 1 classeur grand format
# Feuilles perforées 21 x 29,7
# Intercalaires
# Oeillets
# Ecole Ies Cé&re
# Quetigny
# Matérie\ score
# classe de cM2
# M. Marchand
# Année
# 017-2018
# 1 cahier ou un grand carnet de son choix
# 1 ardoise et le feutre adapté
# 1 agenda
# 3 pinceaux (1 fin, 1 moyen, 1 brosse)
# 1 chiffon
# 1 sac pour le matériel de peinture
# 1 vieux tee-shirt pour la peinture
# 1 paire de chaussons et un sac de rangement

# %%
import openai

# Remplacez 'YOUR_API_KEY' par votre clé API GPT-3
openai.api_key = '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'

# Fonction pour interagir avec ChatGPT
def ask_gpt3(prompt):
    response = openai.Completion.create(
        engine="text-davinci-002",  # Choisissez le moteur GPT-3 que vous souhaitez utiliser
        prompt=prompt,
        max_tokens=150,  # Vous pouvez ajuster cela en fonction de la longueur souhaitée de la réponse
        temperature=0.7,  # Vous pouvez ajuster cela pour contrôler le degré de créativité dans la réponse
        stop=None  # Vous pouvez spécifier une liste de chaînes pour arrêter la génération de texte
    )
    return response.choices[0].text.strip()

# Exemple d'utilisation
prompt ="Extrait la liste des fournitures et de leurs quantités à partir du texte suivant, puis présente les résultats sous la forme d'une liste avec chaque fourniture suivie de sa quantité. Assure-toi d'inclure uniquement les fournitures et leurs quantités dans la liste de sortie. la liste doit contenire les elements et la quantite le separateures entre les element doit etre ; comme ca output dassistant:[element1 5 ,element2  3,element3 8,element4 7]"
text=prompt+'\n\n voici le text: \n\n'+extracted_text
response = ask_gpt3(text)
print(response)
# Out:
# stylos 4; surligneurs 4; crayon 1; gomme 1; taille-crayon 1; regle 1; equerre 1; compas 1; rapporteur 1; ciseaux 1; colle 1; scotch 1; feutres 1; crayons 1; classeur 1; perforees 1; intercalaires 1; oeillets 1; cahier 1; ardoise 1; agenda 1; pinceaux 3; chiffon 1; peinture 1; tee-shirt 1; chaussons 1

# %%
import pandas as pd

# Chaîne de caractères représentant la liste de fournitures et de quantités
input_string = response

# Créer un DataFrame vide nommé "commande"
commande = pd.DataFrame(columns=['nom_produit', 'quantite', 'status'])

# Fonction pour extraire et ajouter une ligne à la commande
def extraire_et_ajouter_ligne(info_produits):
    global commande
    produits_quantites = info_produits.split(';')
    for produit_quantite in produits_quantites:
        produit, quantite = produit_quantite.split()
        commande = commande.append({'nom_produit': produit, 'quantite': int(quantite), 'status': 'en attente'}, ignore_index=True)

# Appeler la fonction pour extraire et ajouter une ligne à la commande
extraire_et_ajouter_ligne(input_string)

# Afficher le DataFrame
print(commande)
# Out:
# C:\Users\GO\AppData\Local\Temp\ipykernel_1324\3906748395.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   commande = commande.append({'nom_produit': produit, 'quantite': int(quantite), 'status': 'en attente'}, ignore_index=True)
# C:\Users\GO\AppData\Local\Temp\ipykernel_1324\3906748395.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   commande = commande.append({'nom_produit': produit, 'quantite': int(quantite), 'status': 'en attente'}, ignore_index=True)
# C:\Users\GO\AppData\Local\Temp\ipykernel_1324\3906748395.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   commande = commande.append({'nom_produit': produit, 'quantite': int(quantite), 'status': 'en attente'}, ignore_index=True)
# ...
